# %%
import random
import nltk


from nltk.corpus import wordnet as wn
food = wn.synset('food.n.02')
foodlist = list(set([w for s in food.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))

place = wn.synset('place.n.02')
placelist = list(set([w for s in place.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))

location = ["In California, ", "Outside of Earth, ","On the Safari Grounds, ", "At the Extension of the Tundra, ", "Within the Breeze on a lonely day at the beach, ", "While hiking the grandest of underwater Volcanoes, ", "Looking for the windiest village to maintain wind energy, ", "Hiding in the depths of Quicksand, ", "Flying at the higher limits of the atmosphere the Speed of the Light, "]
action = [" voted against "," eats "," flies with ", " destroys ", "fights", "voted with", "danced with", "mimics", "transform into"]
transition = [" while holding a ", " during times of conflict with a ", " instead of eating a ", "playing with ", "joking as ", "dressing up as ", "cosplaying as ", "checking up on ", "fighting with ", "fighting against "]

with open("Adjectives.txt", "r") as adj:  #open and read the text file
    adjectives = adj.read()  #give the file a variable name 
    adjectivesUsed = list(map(str,adjectives.split())) #individuals words
    
with open("Names_nanogen.txt", "r") as names:
    names1 = names.read()
    subject = list(map(str,names1.split())) #individuals words

with open("ManoPunk.txt", "r") as file:  #open and read the text file
    allText = file.read()  #give the file a variable name 
    words = list(map(str,allText.split())) #individuals words
    
with open("AppleCrisp_Clean.txt", "r") as cs_1:
    csdip_1 = cs_1.read()
    cs_1_1 = list(map(str,csdip_1.split())) #individuals words

with open("MealFact_Class_Nature_WordAssc_Clean.txt", "r") as cs_MF:
    csdip_MF = cs_MF.read()
    MF_1_1 = list(map(str, csdip_MF.split())) #individuals words
    

for x in location * 7 :
    print(random.choice(location) + random.choice(subject) + " " + random.choice(action) + " " + random.choice(adjectivesUsed) + " " + random.choice(foodlist) + " " +  random.choice(transition) + " " +  random.choice(foodlist))
    print(random.choice(words) + " " +  random.choice(words) + " " +  random.choice(adjectivesUsed) + " " +  random.choice(words) + " "+ random.choice(MF_1_1) + " " +  random.choice(words))
    print(random.choice(transition) + random.choice(placelist) + " " + random.choice(words) + " " +  random.choice(words) + " " +  random.choice(words) + " " +  random.choice(words) + " "+ random.choice(adjectivesUsed)+ " "+ random.choice(MF_1_1) + " " +  random.choice(words))
    print(random.choice(words) + " " +  random.choice(words) + " " +  random.choice(adjectivesUsed) + " " +  random.choice(words) + " "+ random.choice(MF_1_1) + " " +  random.choice(words))
    print(random.choice(transition) + random.choice(placelist) + " " + random.choice(words) + " " +  random.choice(words) + " " +  random.choice(words) + " " +  random.choice(words) + " "+ random.choice(adjectivesUsed)+ " "+ random.choice(MF_1_1) + " " +  random.choice(words))
    print(random.choice(words) + " " +  random.choice(words) + " " +  random.choice(adjectivesUsed) + " " +  random.choice(words) + " "+ random.choice(MF_1_1) + " " +  random.choice(words))
    print(random.choice(transition) + random.choice(placelist) + " " + random.choice(words) + " " +  random.choice(words) + " " +  random.choice(words) + " " +  random.choice(words) + " "+ random.choice(adjectivesUsed)+ " "+ random.choice(MF_1_1) + " " +  random.choice(words) + "\n")
# Out:
# Within the Breeze on a lonely day at the beach, Karlen  flies with  tense ruggelach  while holding a fettuccine_Alfredo
# paid with enchanting as Raspberry resides
# fighting againstsanctum_sanctorum the blocking displayed Horus envious Cr jogs
# to looking nasty agents Raw pest
# checking up onsanctuary to the floor it concerned Athletic heavy
# wandering harsh outrageous of Hen grace
# cosplaying ascolony the desert Manoian with glamorous Nut Nomoli
#
# Within the Breeze on a lonely day at the beach, Kerry voted with witty capulin fighting withgarden_cress
# agents end bad Vast Chop laid
# checking up oncapital top displayed that Through aggressive Syrup from
# present hindering clear Governed Seasoned frolics
# dressing up asTabernacle it exert batches the creepy Duck Through
# Invisible agents tender all Butch it
# fighting againstnerve_center to vex Invisible after shiny Soup Beams
#
# At the Extension of the Tundra, Sherye  destroys  wicked currant joking assmallmouth_bass
# Wild to ill the Oat to
#  while holding a Tabernacle top Vast of snatching envious Vinegar Nomoli
# top vex precious a Seafood the
# playing withhatchery eyes freshness vice of concerned Tuna left
# to around annoying vex Pear Clash
# dressing up ascapital agents wasteland of moment fragile Stuffed laid
#
# At the Extension of the Tundra, Mitzi  voted against  ill cooking_apple fighting againstlingonberry
# freshness Rhonso muddy be Roasted frolics
# fighting againstsanctum_sanctorum all Osirisâ€™ as towards sore Calve heavy
# when by envious out Pie moment
# playing withcentre on be displayed Quench powerful Bean after
# vex Covered exuberant eyes Issue in
# fighting againstcenter to as to after enthusiastic Spice on
#
# In California, Tonya  flies with  average lasagna fighting withquince
# Wild styling frail into Cucumber heavy
# fighting withnerve_centre left prices the wander cute Olive lands
# freshness barren selfish line Ginger end
# fighting withhatchery prowling to top wander quaint Onion moment
# the in angry runs Stain it
# fighting withcapital left disrespect the present fine Bacon displayed
#
# In California, Sheba fights arrogant endive cosplaying asgnocchi
# people on blue-eyed is Poultry prices
# joking assanctuary dome West from which itchy Cinnamon Osirisâ€™
# the frolics eager are Gymnasium people
# playing withcapital line frolics grainy top grumpy Staple barren
# towards acting super not Roasted vex
# dressing up ascapital the harsh energy grace lazy Canister Manoian
#
# Within the Breeze on a lonely day at the beach, Carlita voted with open scarlet_runner_bean cosplaying aspattypan_squash
# from heavy puzzled it Beet to
#  while holding a Tabernacle vice to of Great prickly Tasting runs
# end a odd freshness Pie dim
# joking ascapital Osirisâ€™ Governed it Not frantic Watershed flirt
# carry a gleaming blocking Canned eyes
# checking up onsanctuary present takes pest towards expensive Haunt jogs
#
# Looking for the windiest village to maintain wind energy, Melli fights joyous lobster_tart joking asbaba
# it it bloody batches Township this
# dressing up ascolony harsh prices Wild top better Weasel thirst
# Great wandering cute should Chop Horus
#  instead of eating a colony Great dim to Rhonso bright Green Osirisâ€™
# a traverse combative the Wood Rhonso
#  while holding a sanctum_sanctorum vice vex runs styling fine Oat gods
#
# In California, Bambi  eats  nice sweet_orange joking asguanabana
# Nomoli blocking famous pest Cooked displayed
# dressing up ashatchery blocking towards a should relieved Potato left
# after is cloudy styling Dirt should
# cosplaying ascentre by floor Vast wander pleasant Cuisine lands
# desert the wild all Sauce Not
#  instead of eating a centre line in the dim arrogant Beef exert
#
# At the Extension of the Tundra, Mair  destroys  magnificent blackheart dressing up aspinwheel_roll
# the seems gorgeous it Banana while
# fighting withsanctuary it resides Through Horus gorgeous Boar when
# batches dim cute Nomoli Soda prowling
#  during times of conflict with a nerve_centre from while Quench vice perfect Footed lands
# the batches kind Great Paddy desert
#  while holding a nerve_centre agents frolics vex Osirisâ€™ obnoxious Ginger prowling
#
# Within the Breeze on a lonely day at the beach, Lainey danced with uninterested vol-au-vent fighting withpuff
# the your determined from Beverage the
# fighting withcentre agents in when thirst filthy Chop the
# by on hungry barren Stir not
#  during times of conflict with a nerve_center runs jogs when the obedient Root prowling
# Horus Here gentle as Flock top
#  during times of conflict with a center Clash carry from of annoying Quart top
#
# At the Extension of the Tundra, Adelaida fights lucky top_round  during times of conflict with a fritter
# Manoian to thoughtful agents Sauce that
#  during times of conflict with a colony frolics Invisible for resides uptight Pork disrespect
# in while dull Beams Pumpkin by
# fighting withTabernacle batches wandering to top witty Hen seems
# Nomoli on wide-eyed end Pork batches
# playing withcenter Nonetheless by Nonetheless bounds kind Cheese jogs
#
# On the Safari Grounds, Dela  destroys  wicked loaf joking asseckel
# Covered Nomoli worrisome be Fitness be
# fighting againstholy_of_holies watching batches disrespect blocking clumsy Cucumber Quench
# bounds the splendid of Butter Through
#  during times of conflict with a Tabernacle around grace exert Not tender Pea deciding
# Nonetheless the confused energy Powder agents
#  while holding a colony a line for Not gifted Clam dim
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Darleen fights wandering bluefin joking asvinifera_grape
# dim to witty people Heidi Covered
#  during times of conflict with a center Covered crop the present light Reese the
# Nomoli with magnificent end Fowl a
# joking assanctuary frolics Beams into encompasses vivacious Uniform alot
# runs from muddy Nonetheless Wisconsin a
# cosplaying ascentre desert Osirisâ€™ be through evil Harvest moment
#
# Looking for the windiest village to maintain wind energy, Matilda mimics clean bartlett_pear playing withbaking-powder_biscuit
# the Osirisâ€™ crazy in Lemon when
#  while holding a hatchery a with snatching floor faithful Mango the
# the Horus cruel pest Cocoa a
# cosplaying asTabernacle takes Horus people lands combative Fowl moment
# Horus a busy by Goat Clash
# playing withcapital on to towards to graceful Vegetable the
#
# In California, Ardath  voted against  impossible smoked_mackerel fighting withsquash_pie
# presents A expensive North Vegetable Horus
# cosplaying ascapital out runs eyes a angry Seasoned seems
# grainy floor graceful wandering Barbecue exert
# dressing up ascenter gods to barren presents faithful Pineapple out
# in from blue a Pudding as
# joking assanctuary runs the a paid concerned Bamboo frolics
#
# Looking for the windiest village to maintain wind energy, Chryste  flies with  jealous linguine fighting againstraspberry
# desert Caught clever to Beef all
# checking up onTabernacle in paid people energy graceful Grate paid
# Covered alert clumsy Osirisâ€™ Mushroom when
# dressing up assanctum_sanctorum the all from Caught light Wheat Horus
# seen North exuberant presents Ridge as
# dressing up assanctum_sanctorum resides gods it Horus eager Raspberry frolics
#
# Within the Breeze on a lonely day at the beach, Fara danced with drab chuck_short_ribs checking up oncracked-wheat_bread
# is wandering bored Nomoli Seasoned dim
# fighting withnerve_center Horus the protect seen worrisome Pepper floor
# end like shy of Bread Osirisâ€™
# dressing up assanctuary jogs people agents freshness strange Scout in
# jogs is easy Wild Roasted runs
#  during times of conflict with a center presents in of with grumpy Currency seen
#
# While hiking the grandest of underwater Volcanoes, Naomi fights tense salmon fighting withicaco
# that dim condemned to Olive Quench
# fighting withholy_of_holies traverse line a styling blue-eyed Thug end
# the Manoian lazy styling Breed ability
#  while holding a hatchery jogs moment alot be bad Harvest Not
# by your weary dim Fry when
#  during times of conflict with a boatyard in Invisible Clash encompasses nasty Sponge Remains
#
# On the Safari Grounds, Reeva mimics drab rhubarb_pie fighting againstbosc
# to the angry is Paddy Quench
# joking asTabernacle after exert runs when horrible Ounce displayed
# Not when witty it Thor Osirisâ€™
# fighting withTabernacle exert presents on laid jittery Chili all
# thirst left thoughtful end Lamb flirt
# cosplaying ascenter from to Through deciding tired Beverage seems
#
# Looking for the windiest village to maintain wind energy, Dorris  destroys  enthusiastic cheddar cosplaying assour_cherry
# by by blue desert Accompaniment the
#  while holding a nerve_center to a towards dim repulsive Barbecue wandering
# a alot depressed which Beet not
# joking asboatyard is protect to flirt concerned Jelly pest
# from like shy line Cream Beams
# playing withnerve_center Invisible thirst freshness Remains bewildered Soybean Rhonso
#
# Looking for the windiest village to maintain wind energy, Etty fights better bialystoker  while holding a store_cheese
# to eyes comfortable protect Steamed desert
# cosplaying asnerve_center wasteland exert it seen frightened Spray end
# Vast Osirisâ€™ glamorous dim Sesame line
# cosplaying asholy_of_holies as out wandering top easy Francisco left
# jogs harsh blue all Morris frolics
# dressing up ascolony a A flirt Beams blue Dessert from
#
# In California, Jacky voted with crazy flounder  while holding a fowl
# seems should naughty thirst Lemon the
# playing withnerve_center as Beams Nomoli laid ill Freshly to
# with be inquisitive top Pig a
# cosplaying ascolony freshness when the moment famous Roasted from
# all from victorious like Chop carry
# fighting withcentre for out Through the alive Chop it
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Jena  flies with  proud triple_cream fighting againstalmond_crescent
# looking runs thankful sand Cannabis all
#  instead of eating a holy_of_holies vice Manoian grace harsh comfortable Estuary vice
# vice resides curious carcasses Biscuit seen
# playing withnerve_centre through Governed frolics floor muddy Aggregate frolics
# it the weary people Cinnamon Invisible
# cosplaying ascenter wander Great the Rhonso confused Plant bounds
#
# In California, Lou transform into blue sponge_cake checking up ontournedos
# batches Covered lonely seen Loki of
#  instead of eating a Tabernacle Governed present is A bored Milk disrespect
# the while easy spread Decimal pest
# fighting againstcenter grainy blocking wasteland Beams selfish Slime present
# desert hindering hilarious after Denver towards
# cosplaying assanctum_sanctorum Nonetheless from is freshness glorious Sandwich from
#
# On the Safari Grounds, Sybyl  eats  lonely escarole playing withstriped_bass
# thirst Vast attractive seen Webber be
# checking up onsanctum_sanctorum thirst Rhonso resides Horus awful Pod that
# end desert tough Covered Coffee when
# checking up onholy_of_holies freshness freshness the Osirisâ€™ crazy Seed dim
# by eyes jolly frolics Vegetable all
# playing withcentre Not towards West paid impossible Maize as
#
# Outside of Earth, Shelly  destroys  tough largemouth_bass  during times of conflict with a mozzarella
# Rhonso of impossible sand Oyster of
#  instead of eating a colony hindering to from the uninterested Morris your
# the Not concerned alot Cleaned the
#  during times of conflict with a centre jogs Nomoli that Invisible ashamed Butter barren
# is carcasses ugly agents Flake vice
# fighting againstTabernacle spread snatching the the dead Cheese the
#
# Hiding in the depths of Quicksand, Roby  eats  ugliest honey_cake cosplaying asananas
# end exert nasty jogs Drag the
# cosplaying asTabernacle a hindering line while adorable Coca flirt
# moment bounds poised people Fruit Osirisâ€™
#  during times of conflict with a centre that flirt from Not attractive Colored should
# energy from gleaming thirst Strawberry vex
# fighting withsanctuary is the it vice creepy Rink sand
#
# In California, Harli  destroys  shiny tea_bread joking aschilli
# Osirisâ€™ by tired vice Aroma presents
# joking ascolony that deciding agents Manoian panicky Fuller takes
# is seems repulsive snatching Yemen is
# fighting withcolony runs Nonetheless Manoian all attractive Planter as
# Vast of fancy freshness Planter for
# joking asnerve_center runs it as prices blue-eyed Lemon lands
#
# In California, Eugenia mimics sparkling hackberry  while holding a buttercrunch
# the jogs real into Orleans watching
# fighting againstcolony is through Quench crop healthy Athletic pest
# of thirst expensive inspect Dry Covered
# cosplaying ascentre paid spread out styling mushy Stuffed carry
# jogs present precious dim Chop A
# joking asholy_of_holies top thirst the it vivacious Relish disrespect
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Melli transform into average French_loaf fighting againstgingersnap
# Nonetheless out good seems Flavour through
#  during times of conflict with a boatyard Not Horus from watching successful Pork from
# a which disturbed present Salt Osirisâ€™
# fighting againstnerve_center from the the when fragile Pie exert
# dim frolics bored vex Cabbage that
#  instead of eating a sanctum_sanctorum exert deciding Vast by shy Yam as
#
# While hiking the grandest of underwater Volcanoes, Gracie  eats  bloody saveloy playing withgarden_truck
# all Manoian busy is Sauce presents
# checking up onnerve_centre on Beams to the wild Salad resides
# from Covered ill Horus Chicken Horus
# fighting withcenter the harsh desert Quench mushy Chocolate spread
# vex Horus ashamed Beams Legume Manoian
#  instead of eating a centre it Caught Nomoli Covered wicked Olive flirt
#
# While hiking the grandest of underwater Volcanoes, Dulce fights busy spinach_beet dressing up asmutton
# Quench runs smiling is Ewing frolics
# checking up onhatchery seen the Caught Nomoli fragile Beet Invisible
# out the shy top Ginger Quench
#  while holding a colony Invisible takes wander West worried Peel vice
# in protect arrogant jogs Wrap seems
#  while holding a nerve_centre in eyes traverse snatching famous Pakistani not
#
# Within the Breeze on a lonely day at the beach, Sarette voted with exuberant raisin joking ascroissant
# Manoian should black to Maple A
#  during times of conflict with a sanctuary while lands West Beams brave Sugar North
# Osirisâ€™ towards lucky Osirisâ€™ Bake is
# playing withboatyard people in disrespect from attractive Vinegar desert
# acting hindering modern be Salt seen
# cosplaying assanctum_sanctorum runs is Manoian grace breakable Cheese frolics
#
# Hiding in the depths of Quicksand, Maurita  eats  courageous Camembert checking up onkippered_herring
# a to rich snatching Blue Caught
#  during times of conflict with a holy_of_holies Rhonso of the Rhonso unusual Banana floor
# dim displayed defiant it Peanut moment
# fighting againstcapital jogs a inspect for clear Graft your
# while barren powerful of Carrot a
# playing withcenter it grace Osirisâ€™ grainy amused Sugar looking
#
# Within the Breeze on a lonely day at the beach, Rebekkah voted with doubtful Uruguay_potato fighting againstboxberry
# grace Osirisâ€™ lonely to Baltimore is
# dressing up ascolony as as a is inquisitive Survey Not
# jogs Through fair looking Cucumber North
#  during times of conflict with a center the top all laid uptight Francisco on
# Horus displayed victorious Nonetheless Coconut around
# cosplaying ascentre agents the Caught Beams clever Penny Covered
#
# At the Extension of the Tundra, Hope  eats  strange Cornish_pasty joking asbreadfruit
# Horus into powerful it Chili in
# fighting withnerve_center Nonetheless Nomoli is thirst tough Dry Horus
# in eyes fancy on Crop is
# playing withsanctum_sanctorum barren from Wild alert worrisome Dyed as
# Beams presents weary prices Butter Governed
# playing withhatchery which harsh Wild bounds jittery Rail inspect
#
# While hiking the grandest of underwater Volcanoes, Nicoli fights different Red_Delicious fighting againststrawberry
# resides top smiling agents Ski crops
# dressing up ascapital for to your Horus vast Sauce end
# present to drab that Ash gods
# cosplaying asnerve_center Osirisâ€™ after by heavy upset Vegetable is
# acting alert lovely harsh Basil your
#  instead of eating a center heavy to the Covered sparkling Boiled Here
#
# Outside of Earth, Jobi  voted against  adventurous saltwater_fish  instead of eating a hindshank
# top agents elegant by Sweet floor
# playing withholy_of_holies agents this vex Covered pleasant Yukon of
# sand like exuberant it Kettle Rhonso
# cosplaying ascolony wandering are seems Nonetheless blue Salad in
# vex thirst talented runs Spice Governed
# playing withsanctum_sanctorum it is the Osirisâ€™ upset Peanut Osirisâ€™
#
# While hiking the grandest of underwater Volcanoes, Nina fights lively corn_fritter  instead of eating a elderberry
# crops after old-fashioned the Grazing eyes
#  during times of conflict with a holy_of_holies agents agents out grace smiling Louse the
# a bounds bad of Baking flirt
#  instead of eating a nerve_centre Great to Horus Covered black Squash a
# a to poised thirst Chicken to
# joking asnerve_centre should from a North dizzy Elm is
#
# While hiking the grandest of underwater Volcanoes, Gigi mimics obedient babka joking assausage_roll
# vex blocking nice be Sandwich Not
# cosplaying asnerve_center styling for Nomoli with ugly Vinegar dim
# resides encompasses black eyes Eastman as
#  while holding a capital jogs snatching is sand quaint Sauce vex
# Vast when bright A Butter of
# cosplaying asboatyard in the Horus all funny Pea Invisible
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Siusan  destroys  evil mammee_apple playing withgarambulla
# it from puzzled on Chili Horus
#  during times of conflict with a holy_of_holies eyes paid carry harsh helpless Legume disrespect
# Great floor troubled grace Sprout Vast
# fighting againstcenter the by freshness grace vivacious Soy for
# dim looking strange which Drinker takes
#  while holding a hatchery flirt it A grace motionless Staple runs
#
# In California, Nydia mimics embarrassed radish fighting withlimpet
# Horus bounds elated Vast Chop all
# joking asholy_of_holies of heavy wasteland to determined Cheese Wild
# end freshness eager inspect Stew traverse
# fighting withcapital flirt grainy Horus all evil Britannia by
# left that attractive is Lemon agents
# dressing up asboatyard floor grace that the bright Cookbook seen
#
# At the Extension of the Tundra, Harley mimics vivacious albacore  instead of eating a buffalo
# flirt North obnoxious that Burger Horus
# joking asnerve_centre not this Osirisâ€™ are disturbed Breakfast Not
# Rhonso through frightened gods Dry wasteland
#  instead of eating a sanctuary it of dim crop depressed Hamlet by
# line eyes troubled thirst Herb out
# checking up oncenter Vast of while when disturbed Pie protect
#
# Outside of Earth, Wilie  voted against  drab bonito joking asfilet_mignon
# Covered your elated as Flour the
#  during times of conflict with a nerve_center Nomoli the North be joyous Peanut the
# it is upset alert Bake exert
# joking ascolony Through Caught Nonetheless the plain Nut harsh
# top end homeless from Cabbage Nonetheless
# playing withcentre vex grace on laid outstanding Hydroelectric on
#
# Within the Breeze on a lonely day at the beach, Dorry  eats  nice whelk checking up ongiblet
# that moment doubtful styling Olive ability
#  during times of conflict with a capital frolics grace a a homely Cookbook people
# as runs delightful prices Rupee A
#  while holding a nerve_center from batches inspect from embarrassed Mint the
# grace line attractive Wild Dough that
# playing withhatchery resides runs of be nervous Melon presents
#
# Hiding in the depths of Quicksand, Tildie mimics zealous cruller checking up onpound_cake
# Great pest selfish paid Sweating presents
# fighting againstboatyard to while Manoian vex obedient Spoon alert
# as present helpless protect Clover Governed
#  instead of eating a sanctuary sand a floor dim powerful Fry Governed
# of the condemned paid Tame Rhonso
# fighting withholy_of_holies energy traverse around the foolish Lawn is
#
# Within the Breeze on a lonely day at the beach, Heath fights blue-eyed navel_orange fighting withmad_apple
# left watching itchy towards Melon resides
# fighting withcapital wander encompasses dim eyes mysterious Oven heavy
# from frolics rich when Oil a
#  instead of eating a colony Rhonso a eyes flirt disgusted Baltimore barren
# should while inexpensive this Sugarcane heavy
# dressing up assanctum_sanctorum eyes Horus this all inexpensive Hickory inspect
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Gillian fights precious bosc fighting againstspaghettini
# it seen alert spread Quantity thirst
# cosplaying ascentre inspect when Nomoli encompasses stormy Sesame lands
# when floor inquisitive top Fry as
# dressing up ashatchery the prowling by the clear Camera to
# top flirt busy out Millet inspect
# playing withhatchery Osirisâ€™ vice Nonetheless Here selfish Sausage Nomoli
#
# While hiking the grandest of underwater Volcanoes, Davine  eats  obedient sapodilla  instead of eating a tangelo
# Rhonso batches magnificent takes China all
#  while holding a center agents Horus it heavy nasty Cherry a
# blocking is jittery Nonetheless Mango snatching
# joking assanctuary seems Caught a around drab Peanut the
# Rhonso when helpful desert Pineapple on
#  instead of eating a nerve_center Osirisâ€™ Wild of Not odd Potato it
#
# Within the Breeze on a lonely day at the beach, Jaclyn  voted against  alive smoked_mackerel  instead of eating a vol-au-vent
# seems to uninterested prices Peanut grace
# dressing up assanctum_sanctorum Wild a laid through strange Township resides
# seen carcasses bewildered Beams Milk is
#  instead of eating a nerve_center heavy that Nomoli to funny Soybean present
# takes agents grieving a Bean end
# playing withhatchery seems thirst which while grumpy Sauce grace
#
# On the Safari Grounds, Gena voted with modern green_pepper checking up onasparagus
# Horus the bright bounds Beef for
# checking up onnerve_centre seen the by vex glamorous Diver crops
# ability of tense freshness Denver floor
# fighting withcentre to snatching thirst of alive Cherry a
# acting when charming ability Wheat runs
# fighting againstholy_of_holies thirst to towards Nonetheless disturbed Pineapple seems
#
# On the Safari Grounds, Emelyne mimics easy sweet_calabash dressing up aseggfruit
# towards floor different prowling Pudding Horus
# playing withholy_of_holies with the when seen witty Boiled Through
# takes thirst outrageous disrespect Oven resides
# dressing up assanctum_sanctorum end when laid to jolly Boil presents
# vice Rhonso shiny from Pineapple are
# dressing up asboatyard it floor top harsh joyous Roasted seems
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Marcella  flies with  crowded unleavened_bread  instead of eating a chicken
# like North homely Great Magnum the
#  while holding a Tabernacle the traverse a batches upset Cheese with
# it all adorable Beams Flavour thirst
# checking up onboatyard present it the dim colorful Onion bounds
# jogs desert sparkling pest Approval is
# fighting withcenter line present presents Osirisâ€™ glorious Swimming towards
#
# In California, Modestine  destroys  delightful fruit_bar fighting againstdate
# Through Not bewildered frolics Pineapple flirt
# joking asnerve_centre acting seems styling a expensive Loaf presents
# spread a lonely to Swirl Beams
# joking ascolony Not laid are desert jittery Sauce laid
# in Beams talented Horus Afternoon left
# joking ascentre while is this your zealous Ice all
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Elvera voted with elegant slipskin_grape playing withchicory_escarole
# all inspect wrong to Cheese a
# checking up oncentre towards through as floor annoying Token moment
# eyes be gentle wander Sprout moment
# fighting againstnerve_center wandering alot to jogs easy Olive acting
# barren the fierce in Lamb dim
# playing withboatyard the while the from breakable Curry Wild
#
# Outside of Earth, Madelene  destroys  ugliest windfall fighting withpie_shell
# Great looking fair vex Ham Horus
#  while holding a holy_of_holies your of disrespect the disgusted Merle crop
# a dim witty in Wise Horus
# playing withsanctum_sanctorum grace seems acting that condemned Bread agents
# energy lands obedient Covered Eat snatching
# joking asnerve_center your out energy in famous Peel North
#
# Flying at the higher limits of the atmosphere the Speed of the Light,Bernette voted with thoughtful frozen_yogurt cosplaying astakeaway
# Nomoli Vast long be Herbal freshness
# joking ascolony encompasses North wandering in vivacious Tributary from
# as your mushy protect Cucumber exert
# dressing up asnerve_center Remains in with grace clumsy Sponge floor
# Horus bounds plain out Nut alot
#  instead of eating a nerve_center Here encompasses all a unusual Alcohol towards
#
# Hiding in the depths of Quicksand, Gertrud  voted against  powerful Prima  during times of conflict with a fresh_food
# displayed freshness troubled left Broth eyes
#  instead of eating a nerve_center be Horus Nonetheless by frantic Peeled energy
# watching end aggressive A Yam into
# fighting againsthatchery like acting prices to clean Polo A
# disrespect wander helpless on Biscuit that
#  during times of conflict with a colony Osirisâ€™ grace desert line easy Vinegar be
#
# Within the Breeze on a lonely day at the beach, Marlene danced with outstanding crumpet  during times of conflict with a broccoli_raab
# Nonetheless on handsome carcasses Peanut jogs
#  while holding a colony present people seems like fair Reverse paid
# jogs as depressed of Steak through
# fighting withholy_of_holies presents as after floor crazy Steamed towards
# frolics encompasses super as Black to
# fighting againstcapital Quench presents with of poised Boiled vice
#
# On the Safari Grounds, Gwen  flies with  dull bratwurst joking asrock_lobster
# batches into prickly batches Salt all
# cosplaying asTabernacle when Governed crop your terrible Invertebrate wander
# be Great poor Manoian Sugarcane of
# playing withnerve_center a exert Vast eyes depressed Cow presents
# prices flirt eager dim Kings on
# fighting withboatyard to as the all blue Top your
#
# On the Safari Grounds, Anne-Corinne  flies with  jealous celery  while holding a genip
# people dome beautiful Manoian Paint seems
#  during times of conflict with a capital protect disrespect styling not rich Mushroom it
# not eyes tasty takes Stuffed carry
# fighting againstcolony like thirst of that adventurous Tomato crop
# from the energetic a Sugarcane seems
# dressing up assanctum_sanctorum grace Not to by tasty Alcohol of
#
# Hiding in the depths of Quicksand, Marielle  eats  tough pork_tenderloin checking up onlemonade_mix
# towards top calm wasteland Dairy as
# fighting withnerve_center grace ability on wandering worrisome Bar it
# A Governed witty frolics Grain seen
#  instead of eating a center while wasteland top through beautiful Garlic floor
# out Horus clean Quench Dry jogs
# checking up onnerve_centre for carcasses top dome friendly Cabbage a

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\skyis\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
from nltk.corpus import wordnet as wn
food = wn.synset('food.n.02')
list(set([w for s in food.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))
# Out:
# C:\Users\skyis\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:580: UserWarning: Discarded redundant search for Synset('lunch_meat.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# C:\Users\skyis\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:580: UserWarning: Discarded redundant search for Synset('headcheese.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# C:\Users\skyis\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:580: UserWarning: Discarded redundant search for Synset('haslet.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# C:\Users\skyis\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:580: UserWarning: Discarded redundant search for Synset('leg_of_lamb.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# C:\Users\skyis\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:580: UserWarning: Discarded redundant search for Synset('rack_of_lamb.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# ['guanabana',
#  'pepper',
#  "calves'_liver",
#  'casaba',
#  'redfish',
#  'Rock_Cornish_hen',
#  'black_cherry',
#  'top_round',
#  'crappie',
#  'spring_onion',
#  'apple_pie',
#  'celery_root',
#  'hotcake',
#  'king_salmon',
#  "calf's_tongue",
#  'apricot',
#  'caraway_seed_bread',
#  'coho',
#  'volaille',
#  'avocado',
#  'leafy_vegetable',
#  'soy',
#  'side',
#  'Pablum',
#  'sweet_cup',
#  'halibut',
#  'crisphead_lettuce',
#  'tamarindo',
#  'babka',
#  'ricotta',
#  'fortune_cookie',
#  'beach_plum',
#  'chop',
#  'flitch',
#  'sausage_roll',
#  'swordfish',
#  'currant',
#  'yam',
#  'gray_mullet',
#  'mountain_cranberry',
#  'bluefish',
#  'black_pudding',
#  'baba',
#  'twister',
#  'Oven_Stuffer_Roaster',
#  'pimiento',
#  'Vidalia_onion',
#  'coconut_cake',
#  'side_of_pork',
#  'linguini',
#  'buffalofish',
#  'boysenberry',
#  'linguine',
#  'sowbelly',
#  'pollock',
#  'vol-au-vent',
#  'mullet',
#  'mamey',
#  'jimmies',
#  'ginger_nut',
#  'white_bread',
#  'leftovers',
#  'patty_shell',
#  'foreshank',
#  'dog',
#  'celtuce',
#  'French_loaf',
#  'junk_food',
#  'largemouth_bass',
#  'greengage_plum',
#  'blackberry',
#  'annon',
#  'hen',
#  'Berlin_doughnut',
#  'eclair',
#  'chevre',
#  'tangelo',
#  "devil's_food",
#  'sea_bass',
#  'pepperoni',
#  'shortcake',
#  'headcheese',
#  'parsnip',
#  'cinnamon_bread',
#  'courgette',
#  'black_currant',
#  'lake_trout',
#  'porterhouse',
#  'raised_doughnut',
#  'bridecake',
#  'undercut',
#  'white_bean',
#  'kiwi',
#  'polenta',
#  'side_of_meat',
#  'granadilla',
#  'lanseh',
#  'winter_squash',
#  'corn_dab',
#  'brat',
#  'turtle_bean',
#  'broiler',
#  'fedelline',
#  'amarelle',
#  'beef_neck',
#  'trout',
#  'baguet',
#  'saltwater_fish',
#  'marrow',
#  'lambchop',
#  'surinam_cherry',
#  'winkle',
#  'icaco',
#  'partridge',
#  'root_vegetable',
#  'veau',
#  'onion',
#  'beef',
#  'sweet_roll',
#  'soda_biscuit',
#  'bliny',
#  'king_crab',
#  'pemmican',
#  'ananas',
#  'iceberg',
#  'vegetable',
#  'crab',
#  'raw_meat',
#  'pie_crust',
#  'Delmonico_steak',
#  'Spanish_onion',
#  'Brussels_biscuit',
#  'calamari',
#  'buttermilk_biscuit',
#  'hominy_grits',
#  'sugar_beet',
#  'butternut_squash',
#  'jak',
#  'gumbo',
#  'cos',
#  'flank',
#  'celeriac',
#  'fruitcake',
#  'julienne_vegetable',
#  'frankfurter',
#  'drop_biscuit',
#  'caviar',
#  'neck_sweetbread',
#  'bialy',
#  'stockfish',
#  'pheasant',
#  'string_cheese',
#  'whitebait',
#  'process_cheese',
#  'sea_bream',
#  'whiting',
#  'sockeye',
#  'alfalfa_sprout',
#  'dahl',
#  'rambotan',
#  'Norwegian_lobster',
#  'dog_biscuit',
#  'mad_apple',
#  'snail',
#  'husk_tomato',
#  'horseflesh',
#  'garden_pea',
#  'ribier',
#  'sweet_cherry',
#  'cod',
#  'mutton_chop',
#  'Host',
#  'graham_cracker',
#  'cornmeal_mush',
#  'granola',
#  'confit',
#  'Gouda_cheese',
#  'cut_of_pork',
#  'Fordhooks',
#  'quark_cheese',
#  'collards',
#  'lake_herring',
#  'rutabaga',
#  'kaiser_roll',
#  'unleavened_bread',
#  'chocolate_liquor',
#  'frijole',
#  'eel',
#  'kippered_salmon',
#  'porc',
#  'catfish',
#  'lox',
#  'brick_cheese',
#  'common_bean',
#  'edda',
#  'okra',
#  'graham_bread',
#  'scup',
#  'tamarind',
#  'sailfish',
#  'pilot_biscuit',
#  'bean_sprout',
#  'pineapple',
#  'apple',
#  'European_smelt',
#  'bilberry',
#  'cornbread',
#  'melon',
#  'dried_apricot',
#  'lobster_tart',
#  'duck',
#  'bear_paw',
#  'rusk',
#  'baked_potato',
#  'aitchbone',
#  'jellyroll',
#  'Nova_salmon',
#  'lime',
#  'cling',
#  'cherrystone_clam',
#  'Irish_soda_bread',
#  'wedding_cake',
#  'dewberry',
#  'crape',
#  'Shawnee_cake',
#  'chopsteak',
#  'roast_pork',
#  'summer_crookneck',
#  'winter_melon',
#  'spoon_bread',
#  'pfannkuchen',
#  'clarified_butter',
#  'blade',
#  'ketembilla',
#  'clam',
#  'almond_cookie',
#  'coco_plum',
#  'meat_pie',
#  'cruller',
#  'chicken',
#  'dumplings',
#  'gammon',
#  'pea',
#  'Edam',
#  'chile',
#  'watercress',
#  'sand_dab',
#  'freestone',
#  'egg_noodle',
#  'picnic_ham',
#  'mangel-wurzel',
#  'broccoli_rabe',
#  'milt',
#  'frank',
#  'littleneck_clam',
#  'garbanzo',
#  'citron',
#  'salad_green',
#  'beet',
#  'cracker',
#  'pea_bean',
#  'sardine',
#  'goa_bean',
#  'pork_belly',
#  'baklava',
#  'custard_apple',
#  'citrous_fruit',
#  'sinker',
#  'tortellini',
#  'cooking_apple',
#  'green_soybean',
#  'tagliatelle',
#  'savarin',
#  'nutmeg_melon',
#  'store_cheese',
#  'water_biscuit',
#  'jujube',
#  'cinnamon_roll',
#  'skillet_bread',
#  'saltine',
#  'freshwater_bass',
#  'ground_beef',
#  'duckling',
#  'loaf_of_bread',
#  'orange',
#  'round_steak',
#  'orzo',
#  'French_sorrel',
#  'cusk',
#  'European_blueberry',
#  'crabapple',
#  'offal',
#  'cut',
#  'chitlings',
#  'zwieback',
#  'red_cabbage',
#  'Kentucky_wonder',
#  'matzah',
#  'bok_choy',
#  'chilli',
#  'giblets',
#  'spaghettini',
#  'oatcake',
#  'raisin_bran',
#  'tart',
#  'plum',
#  'hotdog_bun',
#  'chitterlings',
#  'hamburger_roll',
#  'dove',
#  'caviare',
#  'dried_fruit',
#  'carp',
#  'loose-leaf_lettuce',
#  'cheddar_cheese',
#  'poulet',
#  'steamer_clam',
#  'Spanish_lime',
#  'freshwater_bream',
#  'baking_chocolate',
#  'cross_bun',
#  'Indian_mustard',
#  'pastry',
#  'soda_cracker',
#  'breadfruit',
#  'soft-shelled_crab',
#  'couverture',
#  'shoofly_pie',
#  'Swiss_chard',
#  'citrus',
#  'throat_sweetbread',
#  'spaghetti_squash',
#  'chuck_short_ribs',
#  'shrimp',
#  'blade_apple',
#  'crown_roast',
#  'pulassan',
#  'scrod',
#  'cos_lettuce',
#  'periwinkle',
#  'globe_artichoke',
#  'Hershey_bar',
#  'limpet',
#  'navel_orange',
#  'german_pancake',
#  'kitembilla',
#  'wild_plum',
#  'goat_cheese',
#  'roe',
#  'ham',
#  'beef_patty',
#  'chocolate_bar',
#  'witloof',
#  'fish_steak',
#  'beluga_caviar',
#  'cake_mix',
#  'wild_spinach',
#  'flannel_cake',
#  'brown_bread',
#  'cress',
#  'runner_bean',
#  'bowtie_pasta',
#  'takeout',
#  'medlar',
#  'cheesecake',
#  'staff_of_life',
#  'cockle',
#  'Chateaubriand',
#  'shad_roe',
#  'chuck',
#  'pullet',
#  'Jaffa_orange',
#  'baked_goods',
#  'battercake',
#  'dandelion_green',
#  'sponge_cake',
#  'pemican',
#  'fugu',
#  'flapcake',
#  'leechee',
#  'whortleberry',
#  'savoy',
#  'hushpuppy',
#  'chop_steak',
#  'buckwheat_cake',
#  'cabbage',
#  'truffle',
#  'johnny_cake',
#  'soft-shell_clam',
#  'shin',
#  'pigweed',
#  'grey_sole',
#  'Victoria_sponge',
#  'leek',
#  'variety_meat',
#  'bream',
#  'jackfruit',
#  'clover-leaf_roll',
#  'saveloy',
#  'strip_steak',
#  'red_currant',
#  'macaroni',
#  'lychee',
#  'chicory',
#  'canistel',
#  'red_onion',
#  'ackee',
#  'striper',
#  'chocolate_candy',
#  'hot_pepper',
#  'grated_cheese',
#  'bottom_round',
#  'Japanese_crab',
#  'potato_pancake',
#  'quiche_Lorraine',
#  'shell_bean',
#  'juneberry',
#  'pulasan',
#  'croissant',
#  'saskatoon',
#  'Emmental',
#  'ugli_fruit',
#  'cayenne',
#  'teacake',
#  'lemon_meringue_pie',
#  'dark_bread',
#  'hamburger_steak',
#  'picnic_shoulder',
#  'hot_cereal',
#  'oysters_Rockefeller',
#  'fresh_food',
#  'river_prawn',
#  'coconut_macaroon',
#  'doughnut',
#  'pin_bone',
#  'scrag',
#  'roll',
#  'breast_of_lamb',
#  'honey_bun',
#  'rhubarb_pie',
#  'star_fruit',
#  'spice_cake',
#  'biscuit',
#  'key_lime',
#  'scone',
#  'soft-shell_crab',
#  'pigeon_pea',
#  'salsify',
#  'round_clam',
#  'onion_bread',
#  'Boston_brown_bread',
#  'crab_legs',
#  'bap',
#  'drop_scone',
#  'sole',
#  'hasty_pudding',
#  'Seville_orange',
#  'pasty',
#  'kingfish',
#  'avocado_pear',
#  'coconut',
#  'pancake',
#  'Cornish_pasty',
#  'pulse',
#  'oyster',
#  'Brie',
#  'dolphinfish',
#  'serviceberry',
#  'alewife',
#  'buttercrunch',
#  'cocoyam',
#  'liver',
#  'chinook_salmon',
#  'anchovy_pear',
#  'cherrystone',
#  'guava',
#  'beef_jerky',
#  'cookie',
#  'mango',
#  'American_cheese',
#  'double_cream',
#  'loaf_sugar',
#  'pattypan_squash',
#  'matzoh',
#  'white_chocolate',
#  'brioche',
#  'caramel_bun',
#  'savoy_cabbage',
#  'Northern_lobster',
#  'griddlecake',
#  'crescent_roll',
#  'French_endive',
#  'coffee_cake',
#  'rabbit_food',
#  'seedcake',
#  'nan',
#  'coconut_meat',
#  'salt_pork',
#  'bitter_chocolate',
#  'finnan_haddie',
#  'muffin',
#  'Thompson_Seedless',
#  'Parker_House_roll',
#  'hot_cake',
#  'souse',
#  'green_pea',
#  'winter_cress',
#  'gingerbread',
#  'prune',
#  'veggie',
#  'octopus',
#  'cornpone',
#  'morello',
#  'cinnamon_bun',
#  'pond_apple',
#  'smoked_eel',
#  'linguica',
#  'spatchcock',
#  'chips',
#  'anchovy',
#  'tea_bread',
#  'chicory_escarole',
#  'fillet',
#  'soya_bean',
#  'ash_cake',
#  'Rome_Beauty',
#  'yoghurt',
#  'legume',
#  'beigel',
#  'Sally_Lunn',
#  'roast_lamb',
#  'flageolet',
#  'yellow_mombin',
#  'luncheon_meat',
#  'green_pepper',
#  'date-nut_bread',
#  'croaker',
#  'Jewish_rye_bread',
#  'rat_cheese',
#  'salad_burnet',
#  'fresh_foods',
#  'speckled_trout',
#  'buffalo',
#  'honeydew_melon',
#  'Yorkshire_pudding',
#  'slipskin_grape',
#  'apricot_bar',
#  'langoustine',
#  'tostada',
#  'Gouda',
#  'Emmenthaler',
#  'split-pea',
#  'quandang',
#  'milk_chocolate',
#  'white_turnip',
#  'cardoon',
#  'haslet',
#  'cracked-wheat_bread',
#  'gooseberry',
#  'flapjack',
#  'bittersweet_chocolate',
#  'knockwurst',
#  'tangerine',
#  'apple_tart',
#  'cantaloup',
#  'blade_roast',
#  'sea_scallop',
#  'twice-baked_bread',
#  'crepe',
#  'celery',
#  'oxheart',
#  'pork_loin',
#  'butter_bean',
#  'lamb_chop',
#  'julienne',
#  'oyster_plant',
#  'red_herring',
#  'stone_crab',
#  'shoulder',
#  'bran_muffin',
#  'gnocchi',
#  'huckleberry',
#  'pear',
#  'butter_cookie',
#  'Tokay',
#  'butterbean',
#  'chou',
#  'hog_plum',
#  'sprout',
#  'marmalade_plum',
#  'tomatillo',
#  'river_pear',
#  'persimmon',
#  'cowpea',
#  'skillet_corn_bread',
#  'jalapeno_pepper',
#  'rugulah',
#  'shank',
#  'frumenty',
#  'steak_and_kidney_pie',
#  'seeded_raisin',
#  'purple_onion',
#  'mandarin_orange',
#  'cocoa_butter',
#  'sea_trout',
#  'sirloin_steak',
#  'lemon_butter',
#  'hot_cross_bun',
#  'pawpaw',
#  'rack_of_lamb',
#  'berry',
#  'fennel',
#  'sweet_potato',
#  'baguette',
#  'vegetable_oyster',
#  'date',
#  'gobbet',
#  'honey_cake',
#  'ratafia',
#  'tripe',
#  'pastrami',
#  'sultana',
#  'haddock',
#  'ship_biscuit',
#  'deep-dish_pie',
#  'meat',
#  'chocolate_eclair',
#  'roast_veal',
#  'frozen_yogurt',
#  'grits',
#  'flank_steak',
#  'pickled_herring',
#  'Eccles_cake',
#  'cream_cheese',
#  'fettuccini',
#  'poultry',
#  'spaghetti',
#  'Roquefort',
#  'lunch_meat',
#  'light_bread',
#  "pigs'_feet",
#  'liver_sausage',
#  'club_steak',
#  'salmon_loaf',
#  "pigs'_knuckles",
#  'scorzonera',
#  'schnecken',
#  'chard',
#  'rainbow_smelt',
#  'soft_pretzel',
#  'black-eyed_pea',
#  'nonpareil',
#  'chiffon_cake',
#  'plantain',
#  'muscat_grape',
#  'quahog',
#  'mulberry',
#  'Uruguay_potato',
#  'crab_apple',
#  'American_smelt',
#  'lichee',
#  'durian',
#  'Atlantic_salmon',
#  'blintze',
#  'plumcot',
#  'side_of_bacon',
#  'cooky',
#  'tomato',
#  'Golden_Delicious',
#  'coffee_ring',
#  'eggfruit',
#  'red_rockfish',
#  'Camembert',
#  'chop-suey_greens',
#  'bouchee',
#  'lanset',
#  'schrod',
#  'donut',
#  'asparagus',
#  'winter_crookneck_squash',
#  'timbale',
#  'dark_meat',
#  'Baldwin',
#  'lingcod',
#  'Belgian_endive',
#  'lemon',
#  'pitahaya',
#  'blue_cheese',
#  'rose_apple',
#  'gorgonzola',
#  'veal',
#  'jaboticaba',
#  "Grimes'_golden",
#  'navy_bean',
#  'vermicelli',
#  'mince_pie',
#  'grouse',
#  'spiceberry',
#  'summer_squash',
#  'Swiss_cheese',
#  'clingstone',
#  'venison',
#  'puffer',
#  'entrecote',
#  'ready-mix',
#  'vinifera_grape',
#  'netted_melon',
#  'langouste',
#  'napoleon',
#  'smallmouth_bass',
#  'lansa',
#  'yogurt',
#  'Concord_grape',
#  'radicchio',
#  'dumpling',
#  "dragon's_eye",
#  'swedish_turnip',
#  'codfish',
#  'gateau',
#  'roaster',
#  'tourtiere',
#  'feijoa',
#  'Vienna_sausage',
#  'dessert_apple',
#  'cottage_cheese',
#  'pretzel',
#  'Jonathan',
#  'wafer',
#  'prawn',
#  'pumpkin_pie',
#  'sapota',
#  'pot_roast',
#  'fryer',
#  'frier',
#  'American_lobster',
#  'flatbread',
#  'hand_cheese',
#  'squab',
#  'capon',
#  'polony',
#  'gluten_bread',
#  'kitambilla',
#  'broccoli',
#  'toast',
#  'bluefin_tuna',
#  'jumble',
#  "farmer's_cheese",
#  'rabbit',
#  'rump',
#  'chipotle',
#  'long-neck_clam',
#  'lamb_roast',
#  'spinach',
#  'coffee_roll',
#  'cupcake',
#  'chipolata',
#  'pork_sausage',
#  'English_runner_bean',
#  'Muenster',
#  'cake',
#  'bird',
#  'manicotti',
#  'endive',
#  'brownie',
#  'Kentucky_wonder_bean',
#  'bread-stick',
#  'sausage',
#  'pompano',
#  'crayfish',
#  'broccoli_raab',
#  'rockfish',
#  'sugar_snap_pea',
#  'broad_bean',
#  'ghee',
#  'kiwi_fruit',
#  'tongue',
#  'Chinese_celery',
#  'seafood',
#  'shadberry',
#  'genipap',
#  'Red_Delicious',
#  'almond_crescent',
#  'Christmas_cake',
#  'damson',
#  'smoked_haddock',
#  'Chinese_gooseberry',
#  'salt-rising_bread',
#  'suckling_pig',
#  'garden_truck',
#  'slop',
#  'tunny',
#  'butter',
#  'fatback',
#  'citrus_fruit',
#  'perch',
#  'matzah_ball',
#  'haricot_vert',
#  'pumpernickel',
#  'grape',
#  'sorb_apple',
#  'Bermuda_onion',
#  'Virginia_ham',
#  "shepherd's_pie",
#  'natal_plum',
#  'bismark',
#  'waffle',
#  'clementine',
#  'noodle',
#  'giblet',
#  'marble_cake',
#  'birthday_cake',
#  'whole_meal_bread',
#  'leg',
#  'pecan_pie',
#  'corn_muffin',
#  'atole',
#  'steamer',
#  'cranberry',
#  'brain',
#  'joint',
#  'veg',
#  'squash_pie',
#  'bratwurst',
#  'bass',
#  'bran_flake',
#  'spareribs',
#  'strudel',
#  'Japanese_plum',
#  'sour_gourd',
#  'shortbread_cookie',
#  'fritter',
#  'halal',
#  'chocolate',
#  'whelk',
#  'scrag_end',
#  'crawfish',
#  'corn_flake',
#  'game',
#  'yellow_turnip',
#  'sugarloaf',
#  'Nova_Scotia_lox',
#  'matzo',
#  'cisco',
#  'shad',
#  'copra',
#  'blue_crab',
#  'Maine_lobster',
#  'hackberry',
#  'bean',
#  'curly_endive',
#  'TV_dinner',
#  'kidney_pie',
#  'rolled_biscuit',
#  'alligator_pear',
#  'grapefruit',
#  'puff',
#  'kasha',
#  'pilot_bread',
#  'pollack',
#  'native_peach',
#  'radish',
#  'ham_hock',
#  'scampo',
#  'wiener',
#  'fettuccine_Alfredo',
#  'Florence_fennel',
#  'garambulla',
#  'finnan_haddock',
#  'short_ribs',
#  'cayenne_pepper',
#  'akee',
#  'fowl',
#  'meatloaf',
#  'puffed_wheat',
#  'Stilton',
#  'pumpkin',
#  'Yellow_Delicious',
#  'bosc',
#  'minute_steak',
#  'beef_tongue',
#  'sunfish',
#  'liverwurst',
#  'scarlet_runner_bean',
#  'wedge_bone',
#  'hamburger_bun',
#  'hard_roll',
#  'genip',
#  'Italian_bread',
#  'pascal_celery',
#  'net_melon',
#  'kidney_bean',
#  'greengage',
#  'rigatoni',
#  'penne',
#  'biltong',
#  'gingersnap',
#  'litchee',
#  'stomach_sweetbread',
#  'casaba_melon',
#  'Alaska_crab',
#  'leaf_beet',
#  'Armerican_cheddar',
#  'blueberry',
#  'chili_pepper',
#  'neck',
#  'fruit_bar',
#  'elver',
#  'mammee_apple',
#  'corned_beef',
#  'mush',
#  'snapper',
#  'home_fries',
#  'muskmelon',
#  'jalapeno',
#  'mandarin',
#  'finnan',
#  'edible_bean',
#  'lima_bean',
#  'goose',
#  'English_muffin',
#  'pimento',
#  'jerked_meat',
#  'meat_loaf',
#  'stick',
#  'cut_of_beef',
#  'guinea_hen',
#  'bok_choi',
#  'dowdy',
#  'collard_greens',
#  'Emmentaler',
#  'molasses_cookie',
#  'Melba_toast',
#  'rollmops',
#  'Victoria_sandwich',
#  'green',
#  'passion_fruit',
#  'wonton',
#  'beignet',
#  'Gruyere',
#  'Bologna_sausage',
#  'kail',
#  'honeydew',
#  'cold_cuts',
#  'lowbush_cranberry',
#  'muscat',
#  'lentil',
#  'scallop',
#  'muscatel',
#  'Empire',
#  'dodger',
#  'Valencia_orange',
#  'eater',
#  'shaddock',
#  'Chinese_jujube',
#  'Nova_Scotia_salmon',
#  'angel_food_cake',
#  'potherb',
#  'beetroot',
#  'seed_cake',
#  'papaya',
#  'sorb',
#  'veal_roast',
#  'tournedos',
#  'peach',
#  'mutton',
#  'litchi',
#  'rhubarb',
#  'blowfish',
#  'mussel',
#  'chickpea',
#  'Alaskan_king_crab',
#  'raspberry',
#  'soya',
#  'sapodilla_plum',
#  'blueberry_yogurt',
#  'sorrel',
#  'yellowtail_flounder',
#  'porterhouse_steak',
#  'alimentary_paste',
#  'anjou',
#  'brandysnap',
#  'raisin_bread',
#  'Newtown_Wonder',
#  'sea_squab',
#  'pilchard',
#  'date_bread',
#  'gigot',
#  'breast_of_veal',
#  'yak_butter',
#  'pike',
#  'oreo',
#  'butterhead_lettuce',
#  'carambola',
#  'Vienna_roll',
#  'gingerbread_man',
#  'quahaug',
#  'raw_vegetable',
#  'hoecake',
#  'civet_bean',
#  'mushroom',
#  ...]
