# %%
import random

with open("ManoPunk.txt", "r") as file:  #open and read the text file
    allText = file.read()  #give the file a variable name 
    words = list(map(str,allText.split())) #individuals words
    words2 = list(map(str,allText.split())) #indivudals words 2
    words3 = list(map(str,allText.split())) #indivudals words 2
    words4 = list(map(str,allText.split())) #indivudals words 2
    words5 = list(map(str,allText.split())) #indivudals words 2
    
with open("AppleCrisp_Clean.txt", "r") as cs_1:
    csdip_1 = cs_1.read()
    cs_1_1 = list(map(str,csdip_1.split())) #individuals words
    cs_1_2 = list(map(str,csdip_1.split())) #individuals words
    cs_1_3 = list(map(str,csdip_1.split())) #individuals words
    cs_1_4 = list(map(str,csdip_1.split())) #individuals words
    cs_1_5 = list(map(str,csdip_1.split())) #individuals words

with open("MealFact_Class_Nature_WordAssc_Clean.txt", "r") as cs_MF:
    csdip_MF = cs_MF.read()
    MF_1_1 = list(map(str, csdip_MF.split())) #individuals words
    MF_1_2 = list(map(str, csdip_MF.split())) #individuals words
    MF_1_3 = list(map(str, csdip_MF.split())) #individuals words
    MF_1_4 = list(map(str, csdip_MF.split())) #individuals words
    MF_1_5 = list(map(str, csdip_MF.split())) #individuals words

    
for x in words * 3:
    print(random.choice(words) + " " +  random.choice(cs_1_2) + " " +  random.choice(words3) + " " +  random.choice(cs_1_4) + " " +  random.choice(words5) + " " + random.choice(cs_1_1) + " " + random.choice(MF_1_1) + " " + random.choice(cs_1_2) + " " +  random.choice(words3) + " " + random.choice(MF_1_1) + " " + random.choice(words4) + " " +  random.choice(cs_1_5))        

print('\n')     
          
for x in words * 5:

    print(random.choice(MF_1_1) + " " +  random.choice(words) + " " +  random.choice(words3) + " " +  random.choice(cs_1_5) + " " +  random.choice(cs_1_2) + " " + random.choice(cs_1_1) + " " + random.choice(MF_1_4) + " " + random.choice(MF_1_2) + " " +  random.choice(words2) + " " + random.choice(MF_1_4) + " " + random.choice(MF_1_5) + " " +  random.choice(words5))             

print('\n')  
          
for x in words * 3:
    print(random.choice(cs_1_1) + " " +  random.choice(cs_1_2) + " " +  random.choice(words3) + " " +  random.choice(words4) + " " +  random.choice(cs_1_5))
# Out:
# alert Intel of Turnip seen Pumpkin Wembley Cracker agents Strawberry watching Cinnamon
# to Toast North Rum the Pumpkin Tommy Char A Canister encompasses Keynote
# thirst Almond eyes Melon A Cultivar Noodle Slice eyes Swimming grace Aromatic
# in Roasted prowling Cultivar Rhonso Tomato Stuffed Sauce the Hoard the Aromatic
# heavy Smooth present Clean prowling Roast Coca Cultivar while Chicken displayed Skin
# freshness Dm top Apple your Potato Juice Cereal exert Approval A Accent
# with Jelly Beams Nut Caught Autumn Flu Bacon jogs Topping out Pea
# exert Ripe floor Brittle harsh Burned Coffee Bob the Fry of Adobe
# Governed Syrup that Sauce presents Almond Essence Pea the Staple Invisible Apple
# as Glistening runs Discord displayed Bake Cuban Salad Not Milk traverse Plum
# in Gui Great Hera your Laptop Smeared Bob in Sprout to Onion
# protect Flavour wandering Onion towards Android Barbecue Android it Pork laid Onion
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-713b86b89e11> in <module>
# ----> 1 for x in words * 5:
#       2     print(random.choice(MF_1_1) + " " +  random.choice(cs_1_2) + " " +  random.choice(words3) + " " +  random.choice(cs_1_4) + " " +  random.choice(words5) + " " + random.choice(cs_1_1) + " " + random.choice(MF_1_1) + " " + random.choice(cs_1_2) + " " +  random.choice(words3) + " " + random.choice(MF_1_4) + " " + random.choice(words4) + " " +  random.choice(words5))
#
# NameError: name 'words' is not defined
